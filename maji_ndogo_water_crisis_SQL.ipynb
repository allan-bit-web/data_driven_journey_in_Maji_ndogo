# %% [markdown]
#                                    maji mandogo project part 2

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:kinus6363@localhost:3306/md_water_services
# Out:
# 'Connected: root@md_water_services'

# %%
# %sql SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 8 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',)]

# %%
# %%sql
#
# SELECT
#     *
# FROM md_water_services.employee
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor')]

# %% [markdown]
#       no of employee who live in harare,kilimani

# %%
# %%sql
#
# SELECT
#     *
# FROM md_water_services.employee
# WHERE province_name = 'Kilimani' AND town_name = 'harare'
# ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [(58, 'Faridah Khalida', '+99142537684', 'faridah.khalida@ndogowater.gov', '176 Port Said Street', 'Kilimani', 'Harare', 'Pioneer'),
#  (87, 'Pili Xola', '+99682314579', 'pili.xola@ndogowater.gov', '31 Samora Machel Road', 'Kilimani', 'Harare', 'Civil Engineer')]

# %%
# %%sql
#
# SELECT
#     *
# FROM md_water_services.employee
# WHERE province_name = 'Kilimani' AND town_name = 'harare'
# ;

# %% [markdown]
# We notice that the email column has no email.
#
# So our emails will be in the form: first_name.last_name@ndogowater.gov

# %%
# %%sql
#
# SELECT
#       CONCAT(LOWER(REPLACE(employee_name," ",".")),"@ndogowater.gov") AS new_email
# FROM md_water_services.employee
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [('amara.jengo@ndogowater.gov',),
#  ('bello.azibo@ndogowater.gov',),
#  ('bakari.iniko@ndogowater.gov',)]

# %% [markdown]
# updating our email column

# %%
# %%sql
#
# UPDATE
#         md_water_services.employee
# SET
#         email=CONCAT(LOWER(REPLACE(employee_name," ",".")),"@ndogowater.gov");
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 56 rows affected.
# []

# %%
# %%sql
#
# SELECT
#     *
# FROM md_water_services.employee
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor')]

# %%
# %sql DESCRIBE employee;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 8 rows affected.
# [('assigned_employee_id', 'int', 'NO', 'PRI', None, ''),
#  ('employee_name', 'varchar(255)', 'YES', '', None, ''),
#  ('phone_number', 'varchar(15)', 'YES', '', None, ''),
#  ('email', 'varchar(255)', 'YES', '', None, ''),
#  ('address', 'varchar(255)', 'YES', '', None, ''),
#  ('province_name', 'varchar(255)', 'YES', '', None, ''),
#  ('town_name', 'varchar(255)', 'YES', '', None, ''),
#  ('position', 'varchar(255)', 'YES', '', None, '')]

# %% [markdown]
# inspecting whether the phone_number  column is a string
#
# checking the length

# %%
# %%sql
#
# SELECT
#      LENGTH(phone_number) AS phone_number_length
# FROM
#      md_water_services.employee
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(12,), (12,), (12,)]

# %%
# %%sql
#
# SELECT
#      LENGTH(TRIM(phone_number)) AS phone_number_length
# FROM
#      md_water_services.employee
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(12,), (12,), (12,)]

# %%
# %%sql
#
# UPDATE
#       md_water_services.employee
# SET
#       phone_number = TRIM(phone_number);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# []

# %%
# %%sql
#
# SELECT
#     *
# FROM md_water_services.employee
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor')]

# %%
# %%sql
#
# SELECT
#     *
# FROM md_water_services.visits
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40)]

# %% [markdown]
# using the employee table to count how many employees live in each town.

# %%
# %%sql
#
# SELECT DISTINCT
#    town_name,
#
#    COUNT(employee_name) OVER (PARTITION BY town_name ) As num_employees
# FROM
#       md_water_services.employee;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('Dahabu', 6),
#  ('Harare', 5),
#  ('Ilanga', 3),
#  ('Kintampo', 1),
#  ('Lusaka', 4),
#  ('Rural', 29),
#  ('Serowe', 3),
#  ('Yaounde', 1),
#  ('Zanzibar', 4)]

# %%
# %%sql
#
# SELECT DISTINCT
#    town_name,
#
#    COUNT(employee_name) As num_employees
# FROM
#       md_water_services.employee
# GROUP BY town_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('Ilanga', 3),
#  ('Rural', 29),
#  ('Lusaka', 4),
#  ('Zanzibar', 4),
#  ('Dahabu', 6),
#  ('Kintampo', 1),
#  ('Harare', 5),
#  ('Yaounde', 1),
#  ('Serowe', 3)]

# %% [markdown]
# getting the top 3 employee_ids with the highest number of locations visited

# %%
# %%sql
#
# SELECT
#     *
# FROM
#      location
# limit 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('AkHa00000', '2 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00001', '10 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban')]

# %%
# %%sql
#
# SELECT DISTINCT
#     assigned_employee_id,
#     COUNT(visit_count) OVER (PARTITION BY  assigned_employee_id ) AS number_of_visits
# FROM
#      visits
# ORDER BY number_of_visits DESC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(1, 3708), (30, 3676), (34, 3539)]

# %%
# %%sql
#
# SELECT DISTINCT
#     assigned_employee_id,
#     COUNT(visit_count) AS number_of_visits
# FROM
#      visits
# GROUP BY assigned_employee_id
# ORDER BY number_of_visits DESC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(1, 3708), (30, 3676), (34, 3539)]

# %% [markdown]
#           -worst performing employees getting their name and the number of visits for the worst

# %%
# %%sql
#
# SELECT DISTINCT
#     v.assigned_employee_id,
#     COUNT(v.visit_count) AS number_of_visits,
#     e.employee_name
# FROM
#      visits v , employee e
# WHERE v.assigned_employee_id = e.assigned_employee_id
# GROUP BY v.assigned_employee_id
# ORDER BY COUNT(v.visit_count) ASC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(20, 15, 'Kunto Asha'), (22, 143, 'Lesedi Kofi'), (44, 218, 'Wambui Jabali')]

# %% [markdown]
# Query that looks up the employee's info:names,email addresses and phone numbers for our top 3 employee_ids with the highest number of locations visited

# %%
# %%sql
#
# SELECT DISTINCT
#      *
# FROM
#      employee
# LIMIT 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor')]

# %%
# %%sql
#
# SELECT DISTINCT
#     v.assigned_employee_id AS employee_id ,
#      e.employee_name,
#      e.email AS email,
#      e.phone_number AS phone_number,
#     COUNT(visit_count) AS number_of_visits
# FROM
#      visits v,employee e
# WHERE v.assigned_employee_id = e.assigned_employee_id
# GROUP BY employee_id
# ORDER BY number_of_visits DESC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(1, 'Bello Azibo', 'bello.azibo@ndogowater.gov', '+99643864786', 3708),
#  (30, 'Pili Zola', 'pili.zola@ndogowater.gov', '+99822478933', 3676),
#  (34, 'Rudo Imani', 'rudo.imani@ndogowater.gov', '+99046972648', 3539)]

# %% [markdown]
# Analysing locations

# %%
# %%sql
#
# SELECT
#      *
# FROM
#       location
# LIMIT 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('AkHa00000', '2 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00001', '10 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban')]

# %% [markdown]
# A query that counts the number of records per town

# %%
# %%sql
#
# SELECT DISTINCT
#      COUNT(*) AS records_per_town,
#      town_name
# FROM
#      location
# GROUP BY
#        town_name
# ORDER BY records_per_town DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 25 rows affected.
# [(23740, 'Rural'),
#  (1650, 'Harare'),
#  (1090, 'Amina'),
#  (1070, 'Lusaka'),
#  (990, 'Mrembo'),
#  (930, 'Asmara'),
#  (930, 'Dahabu'),
#  (780, 'Kintampo'),
#  (780, 'Ilanga'),
#  (770, 'Isiqalo'),
#  (750, 'Zuri'),
#  (710, 'Amara'),
#  (620, 'Majengo'),
#  (520, 'Pwani'),
#  (510, 'Kofi'),
#  (480, 'Serowe'),
#  (470, 'Bahari'),
#  (460, 'Marang'),
#  (400, 'Abidjan'),
#  (400, 'Bello'),
#  (370, 'Cheche'),
#  (350, 'Deka'),
#  (310, 'Djenne'),
#  (300, 'Zanzibar'),
#  (270, 'Yaounde')]

# %% [markdown]
# A query to count the records per province

# %%
# %%sql
#
# SELECT DISTINCT
#      COUNT(*) AS records_per_province,
#      province_name
# FROM
#      location
# GROUP BY
#        province_name
# ORDER BY records_per_province DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(9510, 'Kilimani'),
#  (8940, 'Akatsi'),
#  (8220, 'Sokoto'),
#  (6950, 'Amanzi'),
#  (6030, 'Hawassa')]

# %% [raw]
# From this table, it's pretty clear that most of the water sources in the survey are situated in small rural communities, scattered across Maji Ndogo.
#
# If we count the records for each province, most of them have a similar number of sources, so every province is well-represented in the survey

# %%
XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXERROR ERRORXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# %%sql
# SELECT
#     province_name,
#     town_name,
#     COUNT(*) AS records_per_town
# FROM
#     location
# GROUP BY
#     province_name,
#     town_name
# ORDER BY
#     province_name ASC,
#     records_per_town DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 31 rows affected.
# [('Akatsi', 'Rural', 6290),
#  ('Akatsi', 'Lusaka', 1070),
#  ('Akatsi', 'Harare', 800),
#  ('Akatsi', 'Kintampo', 780),
#  ('Amanzi', 'Rural', 3100),
#  ('Amanzi', 'Asmara', 930),
#  ('Amanzi', 'Dahabu', 930),
#  ('Amanzi', 'Amina', 670),
#  ('Amanzi', 'Pwani', 520),
#  ('Amanzi', 'Abidjan', 400),
#  ('Amanzi', 'Bello', 400),
#  ('Hawassa', 'Rural', 3900),
#  ('Hawassa', 'Serowe', 480),
#  ('Hawassa', 'Amina', 420),
#  ('Hawassa', 'Deka', 350),
#  ('Hawassa', 'Djenne', 310),
#  ('Hawassa', 'Zanzibar', 300),
#  ('Hawassa', 'Yaounde', 270),
#  ('Kilimani', 'Rural', 5440),
#  ('Kilimani', 'Mrembo', 990),
#  ('Kilimani', 'Harare', 850),
#  ('Kilimani', 'Isiqalo', 770),
#  ('Kilimani', 'Zuri', 750),
#  ('Kilimani', 'Amara', 710),
#  ('Sokoto', 'Rural', 5010),
#  ('Sokoto', 'Ilanga', 780),
#  ('Sokoto', 'Majengo', 620),
#  ('Sokoto', 'Kofi', 510),
#  ('Sokoto', 'Bahari', 470),
#  ('Sokoto', 'Marang', 460),
# ...

# %% [markdown]
# Number of records for each location type

# %%
# %%sql
#
# SELECT DISTINCT
#      COUNT(*) AS num_sources,
#      location_type
# FROM
#      location
# GROUP BY
#        location_type
# ORDER BY num_sources;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [(15910, 'Urban'), (23740, 'Rural')]

# %%
# %%sql
#
# SELECT
#      CONCAT(ROUND(15910/ (15910 + 23740) * 100),'%') AS Urban_percentage,
#      CONCAT(ROUND(23740 / (15910 + 23740) * 100),'%') AS Rural_percentage
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [('40%', '60%')]

# %% [raw]
# We can see that there are more rural sources than urban.
#
#  60% of our water sources are in rural communities across Maji Ndogo

# %% [markdown]
# Diving into the sources

# %%
# %%sql
#
# SELECT
#      *
# FROM
#      water_source
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('AkHa00000224', 'tap_in_home', 956),
#  ('AkHa00001224', 'tap_in_home_broken', 930),
#  ('AkHa00002224', 'tap_in_home_broken', 486),
#  ('AkHa00003224', 'well', 364),
#  ('AkHa00004224', 'tap_in_home_broken', 942)]

# %%
# %%sql
#
# SELECT
#      w.source_id,
#      w.type_of_water_source,
#      v.visit_count
# FROM
#    water_source w,visits v
# WHERE
#     w.source_id = v.source_id
# AND
#    v.visit_count = 1
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 50 rows affected.
# [('SoIl32582224', 'river', 1),
#  ('KiRu28935224', 'well', 1),
#  ('HaRu19752224', 'shared_tap', 1),
#  ('AkLu01628224', 'well', 1),
#  ('AkRu03357224', 'shared_tap', 1),
#  ('KiRu29315224', 'river', 1),
#  ('AkRu05234224', 'tap_in_home_broken', 1),
#  ('KiRu28520224', 'tap_in_home', 1),
#  ('HaZa21742224', 'well', 1),
#  ('AmDa12214224', 'tap_in_home', 1),
#  ('HaRu19725224', 'well', 1),
#  ('KiRu26704224', 'shared_tap', 1),
#  ('SoRu35008224', 'shared_tap', 1),
#  ('AkKi00851224', 'tap_in_home', 1),
#  ('AmDa11956224', 'tap_in_home', 1),
#  ('SoRu35703224', 'well', 1),
#  ('HaRu17502224', 'tap_in_home', 1),
#  ('AkHa00070224', 'well', 1),
#  ('HaSe21263224', 'tap_in_home', 1),
#  ('HaSe21346224', 'well', 1),
#  ('KiHa23304224', 'river', 1),
#  ('KiRu26190224', 'shared_tap', 1),
#  ('HaYa21468224', 'well', 1),
#  ('HaSe21154224', 'tap_in_home', 1),
#  ('AmRu14009224', 'tap_in_home', 1),
# ...

# %%
# %%sql
# SELECT
#    *
# FROM
#     visits
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14),
#  (5, 'KiRu29315', 'KiRu29315224', datetime.datetime(2021, 1, 1, 10, 17), 1, 9, 40),
#  (6, 'AkRu05234', 'AkRu05234224', datetime.datetime(2021, 1, 1, 10, 18), 1, 0, 30),
#  (7, 'KiRu28520', 'KiRu28520224', datetime.datetime(2021, 1, 1, 10, 28), 1, 0, 34),
#  (8, 'HaZa21742', 'HaZa21742224', datetime.datetime(2021, 1, 1, 10, 37), 1, 0, 6),
#  (9, 'AmDa12214', 'AmDa12214224', datetime.datetime(2021, 1, 1, 10, 58), 1, 0, 36)]

# %% [markdown]
# The way I look at this table; we have access to different water source types and the number of people using each source.
# These are the questions that I am curious about.
# 1. How many people did we survey in total?
# 2. How many wells, taps and rivers are there?
# 3. How many people share particular types of water sources on average?
# 4. How many people are getting water from each type of source?

# %%
# %%sql
#
# SELECT
#      SUM(number_of_people_served) AS Total_number_served
# FROM
#      water_source
# ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('27628140'),)]

# %%
# %%sql
#
# SELECT DISTINCT
#   type_of_water_source,
#   COUNT(type_of_water_source) AS number_of_sources
# FROM
#      water_source
# GROUP BY type_of_water_source
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home', 7265),
#  ('tap_in_home_broken', 5856),
#  ('well', 17383),
#  ('shared_tap', 5767),
#  ('river', 3379)]

# %% [markdown]
# Average number of people that are served by each water source

# %%
# %%sql
#
# SELECT DISTINCT
#   type_of_water_source,
#   ROUND(AVG(number_of_people_served)) AS ave_people_per_source
# FROM
#      water_source
# GROUP BY type_of_water_source;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home', Decimal('644')),
#  ('tap_in_home_broken', Decimal('649')),
#  ('well', Decimal('279')),
#  ('shared_tap', Decimal('2071')),
#  ('river', Decimal('699'))]

# %% [markdown]
# Calculating the total number of people served by each type of water source in total and ordering in descending order

# %%
# %%sql
#
# SELECT DISTINCT
#   type_of_water_source,
#   SUM(number_of_people_served) AS population_served
# FROM
#      water_source
# GROUP BY type_of_water_source
# ORDER BY population_served DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('11945272')),
#  ('well', Decimal('4841724')),
#  ('tap_in_home', Decimal('4678880')),
#  ('tap_in_home_broken', Decimal('3799720')),
#  ('river', Decimal('2362544'))]

# %%
# %%sql
#
# SELECT DISTINCT
#   type_of_water_source,
#   SUM(number_of_people_served) AS population_served
# FROM
#      water_source
# WHERE
#      type_of_water_source LIKE('%tap%')
# GROUP BY type_of_water_source
# ORDER BY population_served DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [('shared_tap', Decimal('11945272')),
#  ('tap_in_home', Decimal('4678880')),
#  ('tap_in_home_broken', Decimal('3799720'))]

# %% [markdown]
# To make our insights easier to understand we convert population_served into percentages

# %%
# %%sql
#
# SELECT DISTINCT
#   type_of_water_source,
#   ROUND((SUM(number_of_people_served)/27628140)*100) AS percentage_people_per_source
# FROM
#      water_source
# GROUP BY type_of_water_source
# ORDER BY percentage_people_per_source DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('43')),
#  ('well', Decimal('18')),
#  ('tap_in_home', Decimal('17')),
#  ('tap_in_home_broken', Decimal('14')),
#  ('river', Decimal('9'))]

# %% [raw]
# 43% of our people are using shared taps in their communities, and on average, we saw earlier, that 2000 people share one shared_tap.
#
# By adding tap_in_home and tap_in_home_broken together, we see that 31% of people have water infrastructure installed in their homes, but 45%
# (14/31) of these taps are not working! This isn't the tap itself that is broken, but rather the infrastructure like treatment plants, reservoirs, pipes, and
# pumps that serve these homes that are broken.
# 18% of people are using wells. But only 4916 out of 17383 are clean = 28%

# %% [markdown]
#                       START OF THE SOLUTION

# %% [markdown]
# Rank each type of source based on how many people in total use it.
#
# Rank based on the total people served,group by types

# %%
# %%sql
#
# SELECT DISTINCT
#   type_of_water_source,
#   SUM(number_of_people_served) AS population_served,
#   RANK() OVER (ORDER BY SUM(number_of_people_served) DESC) AS rank_by_population
# FROM
#      water_source
# GROUP BY type_of_water_source
# ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('11945272'), 1),
#  ('well', Decimal('4841724'), 2),
#  ('tap_in_home', Decimal('4678880'), 3),
#  ('tap_in_home_broken', Decimal('3799720'), 4),
#  ('river', Decimal('2362544'), 5)]

# %% [raw]
# Key Insights:
# -we should fix shared taps first, then wells, and so on.

# %% [markdown]
# So create a query to do this, and keep these requirements in mind:
# 1. The sources within each type should be assigned a rank.
# 2. Limit the results to only improvable sources.
# 3. Think about how to partition, filter and order the results set.
# 4. Order the results to see the top of the list.

# %%
XXXXXXXXXXXXXXXXXXXXXXXXXXX ERROR ERROR ERROR ERROR ERROR XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# %%sql
#
# SELECT
#   source_id,
#   type_of_water_source,
#   SUM(number_of_people_served) AS population_served,
#   RANK() OVER (PARTITION BY type_of_water_source ORDER BY SUM(number_of_people_served) DESC) AS rank_by_population
# FROM
#      water_source
# GROUP BY type_of_water_source
# LIMIT 50
# ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.OperationalError) (1055, "Expression #1 of SELECT list is not in GROUP BY clause and contains nonaggregated column 'md_water_services.water_source.source_id' which is not functionally dependent on columns in GROUP BY clause; this is incompatible with sql_mode=only_full_group_by")
# [SQL: SELECT
#   source_id,
#   type_of_water_source,
#   SUM(number_of_people_served) AS population_served,
#   RANK() OVER (PARTITION BY type_of_water_source ORDER BY SUM(number_of_people_served) DESC) AS rank_by_population
# FROM
#      water_source
# GROUP BY type_of_water_source
# LIMIT 50
# ;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# analysing queues

# %%
# %%sql
#
# SELECT
#      *
# FROM
#      visits
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14),
#  (5, 'KiRu29315', 'KiRu29315224', datetime.datetime(2021, 1, 1, 10, 17), 1, 9, 40),
#  (6, 'AkRu05234', 'AkRu05234224', datetime.datetime(2021, 1, 1, 10, 18), 1, 0, 30),
#  (7, 'KiRu28520', 'KiRu28520224', datetime.datetime(2021, 1, 1, 10, 28), 1, 0, 34),
#  (8, 'HaZa21742', 'HaZa21742224', datetime.datetime(2021, 1, 1, 10, 37), 1, 0, 6),
#  (9, 'AmDa12214', 'AmDa12214224', datetime.datetime(2021, 1, 1, 10, 58), 1, 0, 36)]

# %% [markdown]
# Ok, these are some of the things I think are worth looking at:
# 1. How long did the survey take?
# 2. What is the average total queue time for water?
# 3. What is the average queue time on different days?
# 4. How can we communicate this information efficiently?
#
# -we will need to use control flow,DateTime and window functions.

# %% [markdown]
# -calculating how long the survey took by getting the first and last date

# %%
# %%sql
#
# SELECT
#      MAX(time_of_record) AS maximum_time_record
# FROM
#      visits;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(datetime.datetime(2023, 7, 14, 13, 53),)]

# %%
# %%sql
#
# SELECT
#      MIN(time_of_record) AS Minimum_time_record
# FROM
#      visits;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(datetime.datetime(2021, 1, 1, 9, 10),)]

# %%
# %%sql
#
# SELECT
#      DAY(MIN(time_of_record)) AS Day_time_record
# FROM
#      visits
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(1,)]

# %%
# %%sql
#
# SELECT
#
#    DATEDIFF(MAX(time_of_record),MIN(time_of_record)) AS Survey_period
#
# FROM
#      visits;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(924,)]

# %% [raw]
# Key Insight:
#     -We find that the survey took 924 days which is about 2 and a half years.

# %% [markdown]
#       2.Let's see how long people have to queue on average in Maji Ndogo.
#
# Note that many sources like taps_in_home have no queues.
# These are just recorded as 0 in the time_in_queue column, so when we calculate averages, we need to exclude those rows. Try using NULLIF() do to
# this.

# %%
# %%sql
#
# SELECT
#      ROUND(AVG(NULLIF( time_in_queue,0))) AS Avg_queue_time
# FROM
#      visits;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('123'),)]

# %% [raw]
# Key insight:
#
# -I get a queue time of about 123 min. So on average, people take two hours to fetch water if they don't have a tap in their homes

# %% [markdown]
#        3.The average queue time on different days

# %%
# %%sql
#
# SELECT DISTINCT
#      DAYNAME( time_of_record) AS day_of_week,
#      ROUND(AVG(NULLIF( time_in_queue,0))) AS avg_queue_time
#
# FROM
#      visits
# GROUP BY day_of_week;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 7 rows affected.
# [('Friday', Decimal('120')),
#  ('Saturday', Decimal('246')),
#  ('Sunday', Decimal('82')),
#  ('Monday', Decimal('137')),
#  ('Tuesday', Decimal('108')),
#  ('Wednesday', Decimal('97')),
#  ('Thursday', Decimal('105'))]

# %% [raw]
# Key Insight:
#   -Saturdays have much longer queue times compared to the other    days.

# %% [markdown]
#       4.Time of the day people collect water
#   -In simple terms the time during the day people collect water.

# %%
# %%sql
#
# SELECT
#      HOUR(time_of_record) AS hour_of_day,
#     ROUND(AVG(NULLIF( time_in_queue,0))) AS avg_queue_time
# FROM
#      visits
# GROUP BY hour_of_day
# ORDER BY hour_of_day;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 14 rows affected.
# [(6, Decimal('149')),
#  (7, Decimal('149')),
#  (8, Decimal('149')),
#  (9, Decimal('118')),
#  (10, Decimal('114')),
#  (11, Decimal('111')),
#  (12, Decimal('112')),
#  (13, Decimal('115')),
#  (14, Decimal('114')),
#  (15, Decimal('114')),
#  (16, Decimal('114')),
#  (17, Decimal('149')),
#  (18, Decimal('147')),
#  (19, Decimal('168'))]

# %% [raw]
# A format like 06:00 will be easier to read so we format time into a specific display format using TIME_FORMAT(time, format)which takes a time data field and
# converts it into a format like %H:00 which is easy to read

# %%
# %%sql
#
# SELECT
#      TIME_FORMAT(TIME(time_of_record),'%H:00') AS hour_of_day,
#     ROUND(AVG(NULLIF( time_in_queue,0))) AS avg_queue_time
# FROM
#      visits
# GROUP BY hour_of_day
# ORDER BY hour_of_day
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 14 rows affected.
# [('06:00', Decimal('149')),
#  ('07:00', Decimal('149')),
#  ('08:00', Decimal('149')),
#  ('09:00', Decimal('118')),
#  ('10:00', Decimal('114')),
#  ('11:00', Decimal('111')),
#  ('12:00', Decimal('112')),
#  ('13:00', Decimal('115')),
#  ('14:00', Decimal('114')),
#  ('15:00', Decimal('114')),
#  ('16:00', Decimal('114')),
#  ('17:00', Decimal('149')),
#  ('18:00', Decimal('147')),
#  ('19:00', Decimal('168'))]

# %% [raw]
# Key Insight:
#   -we can see that mornings and evenings are the busiest. It looks like people collect water before and after work.

# %%
# %%sql
#
# SELECT
#       TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#        DAYNAME(time_of_record),
#        CASE
#            WHEN DAYNAME(time_of_record) = 'Sunday' THEN time_in_queue
#            ELSE NULL
#        END AS Sunday
# FROM
#        visits
# WHERE
#        time_in_queue != 0
#
# LIMIT 20; -- this exludes other sources with 0 queue times.
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 20 rows affected.
# [('09:00', 'Friday', None),
#  ('09:00', 'Friday', None),
#  ('10:00', 'Friday', None),
#  ('10:00', 'Friday', None),
#  ('11:00', 'Friday', None),
#  ('11:00', 'Friday', None),
#  ('12:00', 'Friday', None),
#  ('12:00', 'Friday', None),
#  ('13:00', 'Friday', None),
#  ('13:00', 'Friday', None),
#  ('13:00', 'Friday', None),
#  ('14:00', 'Friday', None),
#  ('14:00', 'Friday', None),
#  ('15:00', 'Friday', None),
#  ('16:00', 'Friday', None),
#  ('07:00', 'Saturday', None),
#  ('07:00', 'Saturday', None),
#  ('09:00', 'Saturday', None),
#  ('11:00', 'Saturday', None),
#  ('13:00', 'Saturday', None)]

# %%
# %%sql
#
# SELECT
#      TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#      -- Sunday
#      ROUND(AVG(
#           CASE
#           WHEN DAYNAME(time_of_record) = 'Sunday' THEN time_in_queue
#           ELSE NULL
#      END
#           ),0) AS Sunday,
#      -- Monday
#      ROUND(AVG(
#           CASE
#           WHEN DAYNAME(time_of_record) = 'Monday' THEN time_in_queue
#           ELSE NULL
#      END
#           ),0) AS Monday,
#      -- Tuesday
#     ROUND(AVG(
#           CASE
#           WHEN DAYNAME(time_of_record) = 'Tuesday' THEN time_in_queue
#           ELSE NULL
#      END
#           ),0) AS Tuesday,
#      -- Wednesday
#      ROUND(AVG(
#           CASE
#           WHEN DAYNAME(time_of_record) = 'Wednesday' THEN time_in_queue
#           ELSE NULL
#      END
#           ),0) AS Wednesday,
#      -- Thursday
#      ROUND(AVG(
#           CASE
#           WHEN DAYNAME(time_of_record) = 'Thursday' THEN time_in_queue
#           ELSE NULL
#      END
#           ),0) AS Thursday,
#      -- Friday
#      ROUND(AVG(
#           CASE
#           WHEN DAYNAME(time_of_record) = 'Friday' THEN time_in_queue
#           ELSE NULL
#      END
#           ),0) AS Friday,
#      -- Saturday
#      ROUND(AVG(
#           CASE
#           WHEN DAYNAME(time_of_record) = 'Saturday' THEN time_in_queue
#           ELSE NULL
#      END
#           ),0) AS Saturday
# FROM
#      visits
# WHERE
#      time_in_queue != 0 -- this excludes other sources with 0 queue times
# GROUP BY
#      hour_of_day
# ORDER BY
#      hour_of_day;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 14 rows affected.
# [('06:00', Decimal('79'), Decimal('190'), Decimal('134'), Decimal('112'), Decimal('134'), Decimal('153'), Decimal('247')),
#  ('07:00', Decimal('82'), Decimal('186'), Decimal('128'), Decimal('111'), Decimal('139'), Decimal('156'), Decimal('247')),
#  ('08:00', Decimal('86'), Decimal('183'), Decimal('130'), Decimal('119'), Decimal('129'), Decimal('153'), Decimal('247')),
#  ('09:00', Decimal('84'), Decimal('127'), Decimal('105'), Decimal('94'), Decimal('99'), Decimal('107'), Decimal('252')),
#  ('10:00', Decimal('83'), Decimal('119'), Decimal('99'), Decimal('89'), Decimal('95'), Decimal('112'), Decimal('259')),
#  ('11:00', Decimal('78'), Decimal('115'), Decimal('102'), Decimal('86'), Decimal('99'), Decimal('104'), Decimal('236')),
#  ('12:00', Decimal('78'), Decimal('115'), Decimal('97'), Decimal('88'), Decimal('96'), Decimal('109'), Decimal('239')),
# ...

# %% [raw]
# Key Insight:
#   -Now we can compare the queue times for each day, hour by hour.
# 1. Queues are very long on a Monday morning and Monday evening as people rush to get water.
# 2. Wednesday has the lowest queue times, but long queues on Wednesday evening.
# 3. People have to queue pretty much twice as long on Saturdays compared to the weekdays. It looks like people spend their Saturdays queueing
# for water, perhaps for the week's supply?
# 4. The shortest queues are on Sundays, and this is a cultural thing. The people of Maji Ndogo prioritise family and religion, so Sundays are spent
# with family and friends.

# %%
# %%sql
#
# SELECT
#     location_id,
#     time_in_queue,
#     AVG(time_in_queue) OVER (PARTITION BY location_id ORDER BY visit_count) AS total_avg_queue_time
# FROM
#     visits
# WHERE
# visit_count > 1 -- Only shared taps were visited > 1
# ORDER BY
#     location_id, time_of_record
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 20 rows affected.
# [('AkHa00036', 113, Decimal('113.0000')),
#  ('AkHa00036', 229, Decimal('171.0000')),
#  ('AkHa00036', 400, Decimal('247.3333')),
#  ('AkHa00036', 120, Decimal('215.5000')),
#  ('AkHa00036', 185, Decimal('209.4000')),
#  ('AkHa00036', 158, Decimal('200.8333')),
#  ('AkHa00036', 226, Decimal('204.4286')),
#  ('AkHa00090', 50, Decimal('50.0000')),
#  ('AkHa00090', 63, Decimal('56.5000')),
#  ('AkHa00090', 12, Decimal('41.6667')),
#  ('AkHa00090', 62, Decimal('46.7500')),
#  ('AkHa00090', 53, Decimal('48.0000')),
#  ('AkHa00090', 34, Decimal('45.6667')),
#  ('AkHa00090', 40, Decimal('44.8571')),
#  ('AkHa00103', 186, Decimal('186.0000')),
#  ('AkHa00103', 88, Decimal('137.0000')),
#  ('AkHa00103', 237, Decimal('170.3333')),
#  ('AkHa00103', 141, Decimal('163.0000')),
#  ('AkHa00103', 183, Decimal('167.0000')),
#  ('AkHa00103', 179, Decimal('169.0000'))]

# %%
# %%sql
#
# SELECT
#      *
# FROM
#     visits
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14),
#  (5, 'KiRu29315', 'KiRu29315224', datetime.datetime(2021, 1, 1, 10, 17), 1, 9, 40),
#  (6, 'AkRu05234', 'AkRu05234224', datetime.datetime(2021, 1, 1, 10, 18), 1, 0, 30),
#  (7, 'KiRu28520', 'KiRu28520224', datetime.datetime(2021, 1, 1, 10, 28), 1, 0, 34),
#  (8, 'HaZa21742', 'HaZa21742224', datetime.datetime(2021, 1, 1, 10, 37), 1, 0, 6),
#  (9, 'AmDa12214', 'AmDa12214224', datetime.datetime(2021, 1, 1, 10, 58), 1, 0, 36)]

# %%
# %%sql
#
# SELECT
#      *
# FROM
#     visits
# WHERE location_id = 'AkHa00036'
# LIMIT 100;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 8 rows affected.
# [(50761, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 15, 9, 7), 1, 240, 10),
#  (50812, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 16, 8, 4), 2, 113, 10),
#  (50912, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 17, 11, 17), 3, 229, 10),
#  (50974, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 18, 6, 58), 4, 400, 10),
#  (50993, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 19, 10, 15), 5, 120, 10),
#  (51028, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 20, 10, 54), 6, 185, 10),
#  (51103, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 21, 6, 28), 7, 158, 10),
#  (51268, 'AkHa00036', 'AkHa00036224', datetime.datetime(2023, 2, 22, 17, 37), 8, 226, 10)]

# %%
# %%sql
#
# SELECT
# name,
# Year,
# wat_bas_r,
#  LAG(wat_bas_r) OVER (PARTITION BY name ORDER BY Year),
# wat_bas_r - LAG(wat_bas_r) OVER (PARTITION BY name ORDER BY Year)
# FROM
# global_water_access
# ORDER BY
# name
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 20 rows affected.
# [('Afghanistan', 2015, 52.9885, None, None),
#  ('Afghanistan', 2020, 66.3279, 52.9885, 13.339405059814453),
#  ('Albania', 2015, 90.6273, None, None),
#  ('Albania', 2020, 94.0914, 90.6273, 3.4641036987304688),
#  ('Algeria', 2015, 88.3527, None, None),
#  ('Algeria', 2020, 90.0375, 88.3527, 1.6847991943359375),
#  ('American Samoa', 2015, None, None, None),
#  ('American Samoa', 2020, None, None, None),
#  ('Andorra', 2015, 100.0, None, None),
#  ('Andorra', 2020, 100.0, 100.0, 0.0),
#  ('Angola', 2015, 26.7144, None, None),
#  ('Angola', 2020, 27.8082, 26.7144, 1.093801498413086),
#  ('Anguilla', 2015, None, None, None),
#  ('Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 2015, None, None, None),
#  ('Antigua and Barbuda', 2017, None, None, None),
#  ('Argentina', 2015, 92.9837, None, None),
#  ('Argentina', 2020, None, 92.9837, None),
#  ('Armenia', 2015, 99.0548, None, None),
# ...

# %% [markdown]
#                                 maji mandogo project part 3
